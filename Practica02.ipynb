# %% [markdown]
# # Fuentes de datos.
#
# - Archivos CSV
# - Archivos Parquet
# - Base datos SQL
# - Archivos JSON
#
#
# También pueden ser:
#
# - APIs
# - Data Lakes
# - Data Warehouses
# - Web scraping.

# %% [markdown]
# # ¿Qué es un DataFrame de pandas?
#
# Un DataFrame de pandas es una forma de representar y trabajar con datos tabulares. Se puede considerar como una tabla que organiza los datos en filas y columnas, lo que la convierte en una estructura de datos bidimensional. Un DataFrame se puede crear desde cero o se pueden utilizar otras estructuras de datos, como los arrays de NumPy.(https://www-databricks-com.translate.goog/blog/what-is-pandas-dataframe?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es&_x_tr_pto=tc)
#
#       nombre  edad
#  0      Juan    25
#  1       Ana    30
#  2      Luis    28
#
# DataFrame
#  ├── columna "nombre"  →  Series
#  └── columna "edad"    →  Series
#
#
#  ![PANDAS](https://miro.medium.com/v2/resize:fit:640/format:webp/0*Db1YPKqC1rz4MPzV.png)

# %% [markdown]
# # Apache Parquet.
#
# Apache Parquet es un formato de almacenamiento en columnas de código abierto que seutiliza para almacenar, gestionar y analizar de manera eficiente grandes conjuntos de datos.
# A diferencia de los formatos de almacenamiento basados en filas, como CSV o JSON, Parquet organiza los datos en columnas para mejorar el rendimiento de las consultas y reducir los costos de almacenamiento de datos.
# Las organizaciones utilizan diferentes formatos de archivo para satisfacer otras necesidades de datos. Muchos formatos tradicionales organizan los datos en filas, optimizando para transferencias de datos simples y legibilidad.
#
# (https://www.ibm.com/mx-es/think/topics/parquet)

# %%
import pandas as pd

datos_titanic = pd.read_parquet("titanic.parquet",engine = "fastparquet")

# %%
datos_titanic

# %% [markdown]
# # SQL
# ### ¿Qué es una base de datos SQL?
#
# La base de datos SQL es una recopilación de datos visualizada como tablas con filas y columnas. Los datos se almacenan de manera similar a una hoja de cálculo, con columnas que indican los atributos de los datos y filas que describen la entidad u objeto sobre el que se refieren los datos. La mayoría de las bases de datos SQL utilizan el lenguaje de consulta estructurado (SQL) para la interacción entre los usuarios y los datos, de ahí su nombre. Son bases de datos relacionales porque se pueden almacenar relaciones de datos entre tablas.
#
# Por ejemplo, una tabla de productos tiene columnas como el nombre del producto, el tipo, el costo, etc., y una fila contiene los valores de los productos individuales. Una tabla de clientes tiene columnas con los nombres y la información de contacto de los clientes. Puede crear una tercera tabla que vincule los datos de los clientes con los productos que han comprado.
# (https://aws.amazon.com/es/what-is/sql-database/)

# %%
# !pip install sqlalchemy
# !pip install psycopg2-binary

# %%
from sqlalchemy import create_engine
import pandas as pd


# Crear conexión
uri = "postgresql://admin:admin@localhost:5432/pruebadb"
engine = create_engine(uri)
# Leer tabla directo a DataFrame
df = pd.read_sql("select customer_id,company_name,contact_name from customers;", engine)

# %%
df
# Out:
#    customer_id                        company_name             contact_name
# 0        ALFKI                 Alfreds Futterkiste             Maria Anders
# 1        ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2        ANTON             Antonio Moreno Taquería           Antonio Moreno
# 3        AROUT                     Around the Horn             Thomas Hardy
# 4        BERGS                  Berglunds snabbköp       Christina Berglund
# ..         ...                                 ...                      ...
# 86       WARTH                      Wartian Herkku         Pirkko Koskitalo
# 87       WELLI              Wellington Importadora            Paula Parente
# 88       WHITC                White Clover Markets           Karl Jablonski
# 89       WILMK                         Wilman Kala          Matti Karttunen
# 90       WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
# [91 rows x 3 columns]

# %% [markdown]
# # JSON
#
# ### ¿Qué es JSON (JavaScript Object Notation)?
#
# JSON (JavaScript Object Notation) es un formato de texto para almacenar e intercambiar datos de forma legible tanto para humanos como para máquinas. Por ello, JSON es relativamente fácil de aprender y de solucionar problemas. Aunque tiene sus orígenes en JavaScript, se ha convertido en un formato de datos muy potente que simplifica el intercambio de datos entre diversas plataformas y lenguajes de programación. Si te dedicas al desarrollo web, al análisis de datos o a la ingeniería de software, es fundamental que comprendas JSON.
#
# ### Conclusiones clave
#
# -- JSON es un formato de datos popular que suelen utilizar los desarrolladores web para transferir datos entre un servidor y una aplicación web.
# -- Dado que JSON se basa en texto, los humanos pueden leerlo fácilmente y las computadoras pueden entenderlo.
# -- La independencia del lenguaje de JSON lo convierte en un formato ideal para el intercambio de datos entre diferentes lenguajes de programación y plataformas.
# -- Han surgido numerosas bases de datos para almacenar e intercambiar datos en formato JSON.
#
#
#
#
# (https://www.oracle.com/database/what-is-json/)

# %%
import pandas as pd

df = pd.read_json("airports.json")

# %%
df.head()
# Out:
#                                             airports
# 0  {'code': 'ATL', 'name': 'Hartsfield-Jackson At...
# 1  {'code': 'PEK', 'name': 'Beijing Capital Inter...
# 2  {'code': 'DXB', 'name': 'Dubai International',...
# 3  {'code': 'LAX', 'name': 'Los Angeles Internati...
# 4  {'code': 'HND', 'name': 'Tokyo Haneda', 'city'...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
print(df.loc[4])
# Out:
# airports    {'code': 'HND', 'name': 'Tokyo Haneda', 'city'...
# Name: 4, dtype: object

# %%
print(type(df.loc[4]["airports"]))
# Out:
# <class 'dict'>

# %%
print(df.loc[4]["airports"]["code"])
# Out:
# HND

# %% [markdown]
# # API
#
#
# ### ¿Qué es una API?
#
# Una API  es un conjunto de definiciones y protocolos que se utiliza para desarrollar e integrar los sistemas de software de las aplicaciones. Suele considerarse como el contrato entre el usuario y el  proveedor de información, en el cual se establece el contenido que se necesita por parte del consumidor (la llamada) y el que requiere el productor (la respuesta). Por ejemplo, el diseño de una API  de servicio meteorológico podría requerir que el usuario escribiera un código postal  y que el productor diera una respuesta en dos partes: la primera sería la temperatura máxima y la segunda sería la mínima.
#
# ## ¿Qué es una API REST?
#
# Una API de REST es una  interfaz de programación de aplicaciones (API) que sigue los principios de diseño del estilo de la arquitectura REST. REST significa transferencia de estado representacional y consiste en un conjunto de reglas y recomendaciones para diseñar una API web.(https://www.redhat.com/es/topics/api/what-is-a-rest-api)

# %% [markdown]
# https://dragonball-api.com/api-docs

# %%
import requests
respuesta = requests.get("https://dragonball-api.com/api/characters/2")
print(respuesta.status_code)  # 200 = éxito
print(respuesta.json())       # respuesta como diccionario
# Out:
# 200
# ...

# %%
type(respuesta)
# Out:
# requests.models.Response

# %%
respuesta.json()["name"]
# Out:
# 'Vegeta'

# %% [markdown]
# ### REST vs SOAP
# ### ¿Qué son?
# REST — Representational State Transfer. Es un estilo de arquitectura que usa HTTP y generalmente trabaja con JSON.
# SOAP — Simple Object Access Protocol. Es un protocolo estricto que usa XML para intercambiar mensajes.
#
# ![comparación](compara.png)
