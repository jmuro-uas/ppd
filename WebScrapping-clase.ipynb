# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


url = "http://transparencia.uasnet.mx/2023/?seccion=2&subseccion=11"

data = {
    "unidad": "",
    "select_uo": "2700",
    "busqueda_por_uo": ""
}

response = requests.post(url, data=data)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

# Extraer tabla de resultados
tabla = soup.find("table")
lista = []
if tabla:
    for fila in tabla.find_all("tr"):
        celdas = [td.get_text(strip=True) for td in fila.find_all(["td", "th"])]
        if celdas:
            #print(celdas)
            if celdas[2].__contains__("M. ASIG.") or celdas[2].__contains__("PROF."):
                celdas.append(1)
            else:
                celdas.append(0)
            #print(type(celdas))
            lista.append(celdas)
           # df = pd.concat([df, celdas], ignore_index=True)
else:
    print("No se encontró tabla en la respuesta")

# %%
len(lista)
print(lista)

# %%
for i in lista:
    print(i)

# %%
from bs4 import BeautifulSoup
url = "http://transparencia.uasnet.mx/2023/?seccion=2&subseccion=11"
response = requests.get(url)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")
unidades={}
todos_los_selects = soup.find_all("select")
for sel in todos_los_selects:
    for op in sel.find_all("option"):
        unidades[op.get('value', '')] = op.text.strip() 
unidades
# Out:
# {'862': '" CARLOS MARX " JUAN JOSE RIOS',
#  '121': 'ALBERCA OLÍMPICA',
#  '1530': 'ASUNTOS JURÍDICOS MAZATLÁN',
#  '550': 'AUDITORIO DEL CAMPUS RAFAEL BUELNA',
#  '170': 'BIBLIOTECA DE HUMANIDADES',
#  '190': 'BIENESTAR UNIVERSITARIO',
#  '2311': 'BUFETE JURÍDICO CULIACÁN',
#  '3922': 'BUFETE JURIDICO GUAMUCHIL',
#  '3921': 'BUFETE JURIDICO GUASAVE',
#  '4521': 'BUFETE JURIDICO MAZATLÁN',
#  '2312': 'BUFETE JURIDICO NAVOLATO',
#  '1413': 'CAJA GENERAL ZONA SUR',
#  '1415': 'CENTRO CULTURAL UNIVERSITARIO',
#  '675': 'CENTRO DE ASTRONOMÍA (RESERVA ECOLÓGICA DE COSALÁ)',
#  '17': 'CENTRO DE ATENCIÓN ESTUDIANTIL ZONA CENTRO',
#  '970': 'CENTRO DE ATENCION ESTUDIANTIL ZONA NORTE',
#  '920': 'CENTRO DE CÓMPUTO LOS MOCHIS',
#  '1440': 'CENTRO DE CÓMPUTO MAZATLÁN',
#  '451': 'CENTRO DE CÓMPUTO UNIVERSITARIO',
#  '4920': 'CENTRO DE ESTUDIOS SUPERIORES DE EL ROSARIO',
#  '9010': 'CENTRO DE IDIOMAS CULIACÁN',
#  '9620': 'CENTRO DE IDIOMAS GUAMUCHIL',
#  '9610': 'CENTRO DE IDIOMAS GUASAVE',
# ...
