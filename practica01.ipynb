# %% [markdown]
# # Primer paso, extraer los datos de un archivo CSV.

# %%
import pandas as pd
extracted_data = pd.read_csv("conjunto_de_datos_iter_00CSV20.csv")
# Out:
# /var/folders/ck/pg7bynv56nsdnxf0f007y0lc0000gn/T/ipykernel_86586/854634524.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   extracted_data = pd.read_csv("conjunto_de_datos_iter_00CSV20.csv")

# %% [markdown]
# # Verificar el contenido.

# %%
extracted_data.head()
# Out:
#    ENTIDAD         NOM_ENT  MUN                             NOM_MUN   LOC  \
# 0        0  Total nacional    0                      Total nacional     0
# 1        0  Total nacional    0                      Total nacional  9998
# 2        0  Total nacional    0                      Total nacional  9999
# 3        1  Aguascalientes    0  Total de la entidad Aguascalientes     0
# 4        1  Aguascalientes    0  Total de la entidad Aguascalientes  9998
#
#                         NOM_LOC LONGITUD LATITUD ALTITUD     POBTOT  ...  \
# 0                Total nacional      NaN     NaN     NaN  126014024  ...
# 1   Localidades de una vivienda      NaN     NaN     NaN     250354  ...
# 2  Localidades de dos viviendas      NaN     NaN     NaN     147125  ...
# 3           Total de la Entidad      NaN     NaN     NaN    1425607  ...
# 4   Localidades de una vivienda      NaN     NaN     NaN       3697  ...
#
#     VPH_CEL VPH_INTER  VPH_STVP VPH_SPMVPI  VPH_CVJ VPH_SINRTV VPH_SINLTC  \
# ...

# %% [markdown]
# # Transformar datos

# %%
def tranform(data_frame, value):
    return data_frame.loc[data_frame["NOM_ENT"] == value, ["ENTIDAD","NOM_ENT","LOC","POBTOT","POBFEM","POBMAS"]]
transformed_data = tranform(data_frame=extracted_data,value="Sinaloa" )

# %%
transformed_data.head()
# Out:
#         ENTIDAD  NOM_ENT   LOC   POBTOT   POBFEM   POBMAS
# 144314       25  Sinaloa     0  3026943  1532128  1494815
# 144315       25  Sinaloa  9998    20358     8853    11505
# 144316       25  Sinaloa  9999     6701     2062     4639
# 144317       25  Sinaloa     0   459310   233994   225316
# 144318       25  Sinaloa     1   298009   154344   143665

# %% [markdown]
# # Cargar datos.

# %%
def load(data_frame,filename):
    return data_frame.to_csv(filename)
load(data_frame=transformed_data,filename="cleaned_data.csv")
